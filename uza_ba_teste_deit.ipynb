# %%
#An improved version of the menu program introduced at the end of Chapter 4. 
#This version allows the user to choose to see pictures until they opt to exit.
#Written by P.K., December 10, 2004

print """
Making pictures from ASCII characters is very popular.
Here are four examples of animals taken from one of the many collections
of ASCII art to be found on the web. 
You can see more at  http://www.afn.org/~afn39695/collect.htm"""

choice = "z"     # initialise with any value that will set the while loop condition to True
while choice != "e":
    print """
    Choose what you would like to see from the following menu (or e to exit):

    a: A dog

    b: A frog

    c: An owl

    d: A donkey

    e: Exit the program

    """  
    choice = raw_input("Type in your choice (a, b, c, d or e): ")

    if choice == "a":
        print """

      

       
                  |\_'''_/|  
                  | O   O |  
                  (/     \)  
                   \  v  /   
                  /  \=/     
          /\    /     )      
            \\\/ )_ | |       
             \____)_)_)

       """


    elif choice == "b":
        print """



               ___      
              /@^@\  
             (-----)
            (       )
          (\/ // \\\ \/)
          |\\\_\\\ //_//|
          ''   '' ''   ''

        """
    elif choice == "c":
        print """

              ^ - ^
             ( o o )
           /'`  v  `'\ 
           |VvvvvvvvV|
           |\VvvvvvV/|
               " "  

        """
    elif choice == "d":
        print """

        /\          /)
       ( \\\        //)
        \ \\\      // /
         \_\\\||||//_/ 
           / _  _ \ 
           |(O)(O)|
           |      |  
           \      /
            |____|      
           (      )
           ( 0  0 )
            \____/ 


        """


    elif choice == "e":
        print "Goodbye!" 
    else:  #  if user chose anything other than a - e
        print "Sorry, there was an error in your input."
        print "To see pictures, you should have typed in a, b, c or d"
        print "To exit: type e"
# Out:
#   File "<ipython-input-1-64a42bdbb685>", line 9
#     You can see more at  http://www.afn.org/~afn39695/collect.htm"""
#
# ^
# SyntaxError: Missing parentheses in call to 'print'
